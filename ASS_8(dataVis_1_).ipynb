# %% [markdown]
# <a href="https://colab.research.google.com/github/aj-in/DSBDAL-meineArbeit/blob/main/ASS_8(dataVis_1_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=sns.load_dataset("titanic")
df.head(66)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0          0       3    male  22.0      1      0   7.2500        S  Third
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...    ...
# 61         1       1  female  38.0      0      0  80.0000      NaN  First
# 62         0       1    male  45.0      1      0  83.4750        S  First
# 63         0       3    male   4.0      3      2  27.9000        S  Third
# 64         0       1    male   NaN      0      0  27.7208        C  First
# 65         1       3    male   NaN      1      1  15.2458        C  Third
#
#       who  adult_male deck  embark_town alive  alone
# ...

# %%
#filling missing age values

df["age"].fillna(int(df["age"].mean()),inplace=True)

df.head(66)  # missing values filled
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0          0       3    male  22.0      1      0   7.2500        S  Third
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...    ...
# 61         1       1  female  38.0      0      0  80.0000      NaN  First
# 62         0       1    male  45.0      1      0  83.4750        S  First
# 63         0       3    male   4.0      3      2  27.9000        S  Third
# 64         0       1    male  29.0      0      0  27.7208        C  First
# 65         1       3    male  29.0      1      1  15.2458        C  Third
#
#       who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(x='sex',data=df).set(title='Number of Males and Females')


# more males on ship
# Out:
# [Text(0.5, 1.0, 'Number of Males and Females')]

# %%
ax = sns.countplot(x="pclass", data=df).set(title='Pclass vs Count')
# more passegers were from class 3 on titanic

# %%
df["age"].hist()

print("max no of passengers were from 20-40")
# Out:
# max no of passengers were from 20-40

# %%
# 2) Fare vs Count
sns.histplot(df['fare'],kde=True).set(title='Count vs Fare')
# Out:
# [Text(0.5, 1.0, 'Count vs Fare')]
